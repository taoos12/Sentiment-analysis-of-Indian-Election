# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as xp
from textblob import TextBlob

# %%
modi = pd.read_csv(r'C:\Practices\Projects\NLP Projects\Sentiment Analysis of Indian Elections\dataset\modi_reviews.csv')

# %%
rahul = pd.read_csv(r'C:\Practices\Projects\NLP Projects\Sentiment Analysis of Indian Elections\dataset\rahul_reviews.csv')

# %%
modi.head(5)
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet
# 0  @anjanaomkashyap I am seeing you as future #bj...
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...
# 3  PM Modi creates a new record of being the only...
# 4  @abhijitmajumder Appointment of Successor! \n\...

# %%
modi.shape
# Out:
# (25688, 3)

# %%
rahul.shape
# Out:
# (14261, 3)

# %% [markdown]
# if polarity > 0 = +ve sentiment
#
# if polarity < 0 = -ve sentiment

# %%
TextBlob(modi['Tweet'][0]).sentiment
# Out:
# Sentiment(polarity=0.35, subjectivity=0.36250000000000004)

# %%
TextBlob(rahul['Tweet'][10]).sentiment
# Out:
# Sentiment(polarity=-0.3814697265625, subjectivity=0.375)

# %%
modi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25688 entries, 0 to 25687
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25688 non-null  int64
#  1   User        25683 non-null  object
#  2   Tweet       25683 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 602.2+ KB

# %%
modi['Tweet'] = modi['Tweet'].astype(str)
rahul['Tweet'] = rahul['Tweet'].astype(str)
def find_polarity(review):
    return TextBlob(review).sentiment.polarity

# %%
modi['Polarity'] = modi['Tweet'].apply(find_polarity)
rahul['Polarity'] = rahul['Tweet'].apply(find_polarity)

# %%
modi.head()
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet  Polarity
# 0  @anjanaomkashyap I am seeing you as future #bj...  0.350000
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000
# 3  PM Modi creates a new record of being the only...  0.312121
# 4  @abhijitmajumder Appointment of Successor! \n\...  0.098788

# %%
rahul.head()
# Out:
#    Unnamed: 0             User  \
# 0           0     Sunnysweet16
# 1           1    drnitinchaube
# 2           2        mrvivek07
# 3           3    JosephPravinP
# 4           4  VandanaMegastar
#
#                                                Tweet  Polarity
# 0  Wonder why no academic or journalist asks INC ...  0.218750
# 1  Congrats for the change #australiavotes2019 an...  0.000000
# 2  Peopel Say “Govt Ne 70 Years Kya kiya”.\nUnse ...  0.000000
# 3  @ajaymaken @RahulGandhi And as a final touch, ...  0.320000
# 4  #LokSabhaElections2019 Anyone not having mass ... -0.166667

# %%
modi['Label'] =np.where(modi['Polarity'] > 0, 'Positive', 'Negative')

# %%
modi.head()
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet  Polarity     Label
# 0  @anjanaomkashyap I am seeing you as future #bj...  0.350000  Positive
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  Positive
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  Positive
# 3  PM Modi creates a new record of being the only...  0.312121  Positive
# 4  @abhijitmajumder Appointment of Successor! \n\...  0.098788  Positive

# %%
modi['Label'][modi['Polarity'] == 0] = 'Neutral'
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\957956197.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   modi['Label'][modi['Polarity'] == 0] = 'Neutral'
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\957956197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modi['Label'][modi['Polarity'] == 0] = 'Neutral'

# %%
rahul['Label'] = np.where(rahul['Polarity'] > 0, 'Positive', 'Negative')

# %%
rahul['Label'][rahul['Polarity'] == 0] = 'Neutral'
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\3682629239.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   rahul['Label'][rahul['Polarity'] == 0] = 'Neutral'
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\3682629239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rahul['Label'][rahul['Polarity'] == 0] = 'Neutral'

# %%
modi.head()
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet  Polarity     Label
# 0  @anjanaomkashyap I am seeing you as future #bj...  0.350000  Positive
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  Positive
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  Positive
# 3  PM Modi creates a new record of being the only...  0.312121  Positive
# 4  @abhijitmajumder Appointment of Successor! \n\...  0.098788  Positive

# %%
rahul.head()
# Out:
#    Unnamed: 0             User  \
# 0           0     Sunnysweet16
# 1           1    drnitinchaube
# 2           2        mrvivek07
# 3           3    JosephPravinP
# 4           4  VandanaMegastar
#
#                                                Tweet  Polarity     Label
# 0  Wonder why no academic or journalist asks INC ...  0.218750  Positive
# 1  Congrats for the change #australiavotes2019 an...  0.000000   Neutral
# 2  Peopel Say “Govt Ne 70 Years Kya kiya”.\nUnse ...  0.000000   Neutral
# 3  @ajaymaken @RahulGandhi And as a final touch, ...  0.320000  Positive
# 4  #LokSabhaElections2019 Anyone not having mass ... -0.166667  Negative

# %%
rahul['Label'].value_counts()
# Out:
# Label
# Positive    6198
# Neutral     4894
# Negative    3169
# Name: count, dtype: int64

# %%
modi['Label'].value_counts()
# Out:
# Label
# Positive    12445
# Neutral      8207
# Negative     5036
# Name: count, dtype: int64

# %%
rahul = rahul[rahul['Label'] != 'Neutral']

# %%
rahul['Label'].value_counts()
# Out:
# Label
# Positive    6198
# Negative    3169
# Name: count, dtype: int64

# %%
modi = modi[modi['Label'] != 'Neutral']

# %%
modi['Label'].value_counts()
# Out:
# Label
# Positive    12445
# Negative     5036
# Name: count, dtype: int64

# %%
print(modi.shape)
print(rahul.shape)
# Out:
# (17481, 5)
# (9367, 5)

# %%
np.random.seed(10)
remove_n = 8481
drop_indices = np.random.choice(modi.index, remove_n, replace= False)
df_modi = modi.drop(drop_indices)

# %%
df_modi.shape
# Out:
# (9000, 5)

# %%
np.random.seed(10)
remove_n = 367
drop_indices =  np.random.choice(rahul.index, remove_n, replace= False)
df_rahul = rahul.drop(drop_indices)

# %%
print(df_modi.shape)
print(df_rahul.shape)
# Out:
# (9000, 5)
# (9000, 5)

# %%
modi_count = df_modi.groupby('Label').count()

# %%
neg_modi = (modi_count['Polarity'][0] / 1000) * 100
pos_modi = (modi_count['Polarity'][1] / 1000) * 100
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\553255817.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   neg_modi = (modi_count['Polarity'][0] / 1000) * 100
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\553255817.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_modi = (modi_count['Polarity'][1] / 1000) * 100

# %%
rahul_count = df_rahul.groupby('Label').count()

# %%
rahul_count
# Out:
#           Unnamed: 0  User  Tweet  Polarity
# Label
# Negative        3039  3039   3039      3039
# Positive        5961  5961   5961      5961

# %%
neg_rahul = (rahul_count['Polarity'][0] / 1000) * 100
pos_rahul = (rahul_count['Polarity'][1] / 1000) * 100
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\2548231019.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   neg_rahul = (rahul_count['Polarity'][0] / 1000) * 100
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_27308\2548231019.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_rahul = (rahul_count['Polarity'][1] / 1000) * 100

# %%
pos_rahul
# Out:
# np.float64(596.1)

# %%
politicians = ['Modi', 'Rahul']

neg_list = [neg_modi, neg_rahul]
pos_list = [pos_modi, pos_rahul]

fig = go.Figure(
    data = [
        go.Bar(name= 'Negative', x= politicians, y= neg_list),
        go.Bar(name= 'Positive', x= politicians, y= pos_list)
    ]
)

fig.update_layout(barmode= 'group')
fig.show()
